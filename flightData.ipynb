# %%
#pip install mlxtend

# %%
import pandas as pd
import atoti as tt
from mlxtend.preprocessing import TransactionEncoder
# Out:
# Welcome to atoti 0.7.1!
#
# By using this community edition, you agree with the license available at https://docs.atoti.io/latest/eula.html.
# Browse the official documentation at https://docs.atoti.io.
# Join the community at https://www.atoti.io/register.
#
# atoti collects telemetry data, which is used to help understand how to improve the product.
# If you don't wish to send usage data, set the ATOTI_DISABLE_TELEMETRY environment variable to True.
#
# You can hide this message by setting the ATOTI_HIDE_EULA_MESSAGE environment variable to True.

# %% [markdown]
# ------------------------------------------------------------------------------------------
#
# ## Membaca Data

# %% [markdown]
# import aircraft csv

# %%
dt_aircrafts = pd.read_csv("data/flight/dataAircrafts.csv")

# %%
dt_aircrafts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 470000 entries, 0 to 469999
# Data columns (total 27 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   icao24               469999 non-null  object
#  1   registration         432041 non-null  object
#  2   manufacturericao     149681 non-null  object
#  3   manufacturername     429504 non-null  object
#  4   model                431593 non-null  object
#  5   typecode             177183 non-null  object
#  6   serialnumber         427894 non-null  object
#  7   linenumber           982 non-null     object
#  8   icaoaircrafttype     149551 non-null  object
#  9   operator             24118 non-null   object
#  10  operatorcallsign     40849 non-null   object
#  11  operatoricao         42216 non-null   object
#  12  operatoriata         8015 non-null    object
#  13  owner                427012 non-null  object
#  14  testreg              297 non-null     object
#  15  registered           62839 non-null   object
#  16  reguntil             261513 non-null  object
#  17  status               0 non-null       float64
#  18  built                246215 non-null  object
#  19  firstflightdate      295 non-null     object
#  20  seatconfiguration    0 non-null       float64
#  21  engines              265486 non-null  object
#  22  modes                470000 non-null  bool
#  23  adsb                 470000 non-null  bool
#  24  acars                470000 non-null  bool
#  25  notes                263 non-null     object
#  26  categoryDescription  119784 non-null  object
# dtypes: bool(3), float64(2), object(22)
# memory usage: 87.4+ MB

# %%
dt_aircrafts.isnull().sum()
# Out:
# icao24                      1
# registration            37959
# manufacturericao       320319
# manufacturername        40496
# model                   38407
# typecode               292817
# serialnumber            42106
# linenumber             469018
# icaoaircrafttype       320449
# operator               445882
# operatorcallsign       429151
# operatoricao           427784
# operatoriata           461985
# owner                   42988
# testreg                469703
# registered             407161
# reguntil               208487
# status                 470000
# built                  223785
# firstflightdate        469705
# seatconfiguration      470000
# engines                204514
# modes                       0
# adsb                        0
# acars                       0
# notes                  469737
# categoryDescription    350216
# dtype: int64

# %%
dt_aircrafts = dt_aircrafts.dropna(subset = ["model"])

# %% [markdown]
# import airports csv

# %%
dt_airports = pd.read_csv("data/flight/dataAirports.csv")

# %%
dt_airports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74080 entries, 0 to 74079
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   icao           74080 non-null  object
#  1   name           73050 non-null  object
#  2   iata           8787 non-null   object
#  3   latitude       73049 non-null  float64
#  4   lingitude      73049 non-null  float64
#  5   country        73049 non-null  object
#  6   altitude       59537 non-null  float64
#  7   type           73049 non-null  object
#  8   municipality;  73049 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 5.1+ MB

# %%
dt_airports.isnull().sum()
# Out:
# icao                 0
# name              1030
# iata             65293
# latitude          1031
# lingitude         1031
# country           1031
# altitude         14543
# type              1031
# municipality;     1031
# dtype: int64

# %%
dt_airports = dt_airports.dropna(subset = ["name"])

# %% [markdown]
# import flights csv

# %%
dt_flights = pd.read_csv("data/flight/dataFlights.csv")

# %%
dt_flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12661 entries, 0 to 12660
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   icao24                            12661 non-null  object
#  1   firstSeen                         12661 non-null  int64
#  2   estDepartureAirport               8239 non-null   object
#  3   lastSeen                          12661 non-null  int64
#  4   estArrivalAirport                 8879 non-null   object
#  5   callsign                          12634 non-null  object
#  6   estDepartureAirportHorizDistance  8239 non-null   float64
#  7   estDepartureAirportVertDistance   8239 non-null   float64
#  8   estArrivalAirportHorizDistance    8879 non-null   float64
#  9   estArrivalAirportVertDistance     8879 non-null   float64
#  10  departureAirportCandidatesCount   12661 non-null  int64
#  11  arrivalAirportCandidatesCount     12661 non-null  int64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 1.2+ MB

# %%
dt_flights.isnull().sum()
# Out:
# icao24                                 0
# firstSeen                              0
# estDepartureAirport                 4422
# lastSeen                               0
# estArrivalAirport                   3782
# callsign                              27
# estDepartureAirportHorizDistance    4422
# estDepartureAirportVertDistance     4422
# estArrivalAirportHorizDistance      3782
# estArrivalAirportVertDistance       3782
# departureAirportCandidatesCount        0
# arrivalAirportCandidatesCount          0
# dtype: int64

# %%
dt_flights = dt_flights.dropna(subset = ["estDepartureAirport","estArrivalAirport"])

# %% [markdown]
# create dataframe

# %%
dfAircraft = pd.DataFrame(dt_aircrafts, columns=['icao24','manufacturername'])

# %%
dfAircraft['manufacturername'].value_counts()
# Out:
# Cessna                     72157
# Piper                      44485
# Beech                      18321
# Boeing                     15327
# Cessna Aircraft Company     9687
#                            ...
# Charles M Wyndham              1
# Freeman Michael G              1
# Marv & Ritch                   1
# Pion M V/pion K A              1
# Ronald Kodimer                 1
# Name: manufacturername, Length: 40120, dtype: int64

# %%
dfAircraft.head()
# Out:
#    icao24               manufacturername
# 1  ae267b                   Aerospatiale
# 2  a4fa61                          Piper
# 3  c04101  Champion Aircraft Corporation
# 4  391927                          Robin
# 5  a61cf6             Cirrus Design Corp

# %%
dfAirport = pd.DataFrame(dt_airports, columns=['icao', 'name', 'country'])

# %%
dfAirport.head()
# Out:
#    icao                                name        country
# 0   00A                   Total Rf Heliport  United States
# 1  00AA                Aero B Ranch Airport  United States
# 2  00AK                        Lowell Field  United States
# 3  00AL                        Epps Airpark  United States
# 4  00AR  Newport Hospital & Clinic Heliport  United States

# %%
dfFlight = pd.DataFrame(dt_flights, columns=['icao24', 'estDepartureAirport', 'estArrivalAirport','firstSeen','lastSeen'])

# %%
dfFlight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5499 entries, 0 to 12659
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   icao24               5499 non-null   object
#  1   estDepartureAirport  5499 non-null   object
#  2   estArrivalAirport    5499 non-null   object
#  3   firstSeen            5499 non-null   int64
#  4   lastSeen             5499 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 257.8+ KB

# %% [markdown]
# join data frame

# %%
df_merge1 = pd.merge(dfFlight, dfAircraft, left_on='icao24', right_on='icao24')

# %%
df_merge1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4061 entries, 0 to 4060
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   icao24               4061 non-null   object
#  1   estDepartureAirport  4061 non-null   object
#  2   estArrivalAirport    4061 non-null   object
#  3   firstSeen            4061 non-null   int64
#  4   lastSeen             4061 non-null   int64
#  5   manufacturername     3894 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 222.1+ KB

# %%
df_merge2 = pd.merge(df_merge1, dfAirport, left_on='estDepartureAirport', right_on='icao')

# %%
df_merge3 = pd.merge(df_merge2, dfAirport, left_on='estArrivalAirport', right_on='icao')

# %%
df_merge3.head()
# Out:
#    icao24 estDepartureAirport estArrivalAirport   firstSeen    lastSeen  \
# 0  a2b1ab                KBOI              KNZY  1669334879  1669340957
# 1  ac2038                KLAS              KNZY  1669334418  1669336823
# 2  ac0094                KLAS              KNZY  1669335975  1669338434
# 3  a13c43                KSJC              KNZY  1669337690  1669341266
# 4  abf29f                KSFO              KNZY  1669335167  1669338839
#
#   manufacturername icao_x                                           name_x  \
# 0           Boeing   KBOI                   Boise Air Terminal/Gowen Field
# 1           Boeing   KLAS                 Harry Reid International Airport
# 2           Boeing   KLAS                 Harry Reid International Airport
# 3      Embraer S A   KSJC  Norman Y. Mineta San Jose International Airport
# 4           Boeing   KSFO              San Francisco International Airport
#
#        country_x icao_y                                       name_y  \
# 0  United States   KNZY  North Island Naval Air Station-Halsey Field
# 1  United States   KNZY  North Island Naval Air Station-Halsey Field
# 2  United States   KNZY  North Island Naval Air Station-Halsey Field
# 3  United States   KNZY  North Island Naval Air Station-Halsey Field
# 4  United States   KNZY  North Island Naval Air Station-Halsey Field
#
#        country_y
# 0  United States
# 1  United States
# 2  United States
# 3  United States
# 4  United States

# %%
df_merge3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3881 entries, 0 to 3880
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   icao24               3881 non-null   object
#  1   estDepartureAirport  3881 non-null   object
#  2   estArrivalAirport    3881 non-null   object
#  3   firstSeen            3881 non-null   int64
#  4   lastSeen             3881 non-null   int64
#  5   manufacturername     3721 non-null   object
#  6   icao_x               3881 non-null   object
#  7   name_x               3881 non-null   object
#  8   country_x            3881 non-null   object
#  9   icao_y               3881 non-null   object
#  10  name_y               3881 non-null   object
#  11  country_y            3881 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 394.2+ KB

# %%
df_merge3.isnull().sum()
# Out:
# icao24                   0
# estDepartureAirport      0
# estArrivalAirport        0
# firstSeen                0
# lastSeen                 0
# manufacturername       160
# icao_x                   0
# name_x                   0
# country_x                0
# icao_y                   0
# name_y                   0
# country_y                0
# dtype: int64

# %% [markdown]
# ------------------------------------------------------------------------------------------
#
# ## Mencari Insight dengan Atoti Data Cube

# %%
session = tt.Session()

# %%
ttFlight = session.read_pandas(dfFlight,
                              keys=["icao24","firstSeen","lastSeen","estDepartureAirport","estArrivalAirport"],
                              table_name="table_flights")

# %%
ttAircraft = session.read_pandas(dfAircraft,
                                keys=["icao24","manufacturername"],
                                table_name="table_aircraft")

# %%
ttAirport = session.read_pandas(dfAirport,
                               keys=["icao","country"],
                               table_name="table_airports")

# %%
ttFlight.join(ttAircraft, mapping={"icao24":"icao24"})

# %%
ttFlight.join(ttAirport, mapping={"estDepartureAirport":"icao"})

# %%
ttFlight.join(ttAirport, mapping={"estArrivalAirport":"icao"})

# %%
cube = session.create_cube(ttFlight)

# %%
m = cube.measures

# %%
m["departureCount"] = tt.agg.count(ttFlight["firstSeen"])

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# ------------------------------------------------------------------------------------------
#
# ## Melakukan Association Rule Mining dengan Algoritma Apriori dan Library Mlextend

# %%
import numpy as np
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# %%
df_table = pd.pivot_table(df_merge3, values=['country_x', 'country_y'], index=['manufacturername'], columns=['firstSeen'], aggfunc=np.sum)
df_table
# Out:
#                          country_x                                   \
# firstSeen               1669334405 1669334408 1669334414 1669334418
# manufacturername
# Aero Commander                 NaN        NaN        NaN        NaN
# Aero Vodochody                 NaN        NaN        NaN        NaN
# Aerospatiale                   NaN        NaN        NaN        NaN
# Aerospatiale Industries        NaN        NaN        NaN        NaN
# Aerospatiale/aeritalia         NaN        NaN        NaN        NaN
# ...                            ...        ...        ...        ...
# Turczany Robert                NaN        NaN        NaN        NaN
# Vans                           NaN        NaN        NaN        NaN
# Veenker Harlen G               NaN        NaN        NaN        NaN
# Yakovlev                       NaN        NaN        NaN        NaN
# Zipfell Mw                     NaN        NaN        NaN        NaN
#
#                                                                      \
# firstSeen               1669334428 1669334437 1669334444 1669334448
# manufacturername
# Aero Commander                 NaN        NaN        NaN        NaN
# Aero Vodochody                 NaN        NaN        NaN        NaN
# Aerospatiale                   NaN        NaN        NaN        NaN
# Aerospatiale Industries        NaN        NaN        NaN        NaN
# Aerospatiale/aeritalia         NaN        NaN        NaN        NaN
# ...                            ...        ...        ...        ...
# Turczany Robert                NaN        NaN        NaN        NaN
# Vans                           NaN        NaN        NaN        NaN
# Veenker Harlen G               NaN        NaN        NaN        NaN
# Yakovlev                       NaN        NaN        NaN        NaN
# Zipfell Mw                     NaN        NaN        NaN        NaN
#
#                                                ...  country_y             \
# firstSeen               1669334451 1669334463  ... 1669376348 1669376358
# manufacturername                               ...
# Aero Commander                 NaN        NaN  ...        NaN        NaN
# Aero Vodochody                 NaN        NaN  ...        NaN        NaN
# Aerospatiale                   NaN        NaN  ...        NaN        NaN
# Aerospatiale Industries        NaN        NaN  ...        NaN        NaN
# Aerospatiale/aeritalia         NaN        NaN  ...        NaN        NaN
# ...                            ...        ...  ...        ...        ...
# Turczany Robert                NaN        NaN  ...        NaN        NaN
# Vans                           NaN        NaN  ...        NaN        NaN
# Veenker Harlen G               NaN        NaN  ...        NaN        NaN
# Yakovlev                       NaN        NaN  ...        NaN        NaN
# Zipfell Mw                     NaN        NaN  ...        NaN        NaN
#
#                                                                      \
# firstSeen               1669376400 1669376430 1669376443 1669376468
# manufacturername
# Aero Commander                 NaN        NaN        NaN        NaN
# Aero Vodochody                 NaN        NaN        NaN        NaN
# Aerospatiale                   NaN        NaN        NaN        NaN
# Aerospatiale Industries        NaN        NaN        NaN        NaN
# Aerospatiale/aeritalia         NaN        NaN        NaN        NaN
# ...                            ...        ...        ...        ...
# Turczany Robert                NaN        NaN        NaN        NaN
# Vans                           NaN        NaN        NaN        NaN
# Veenker Harlen G               NaN        NaN        NaN        NaN
# Yakovlev                       NaN        NaN        NaN        NaN
# Zipfell Mw                     NaN        NaN        NaN        NaN
#
#
# firstSeen               1669376623 1669376659 1669376748 1669376915
# manufacturername
# Aero Commander                 NaN        NaN        NaN        NaN
# Aero Vodochody                 NaN        NaN        NaN        NaN
# Aerospatiale                   NaN        NaN  Australia        NaN
# Aerospatiale Industries        NaN        NaN        NaN        NaN
# Aerospatiale/aeritalia         NaN        NaN        NaN        NaN
# ...                            ...        ...        ...        ...
# Turczany Robert                NaN        NaN        NaN        NaN
# Vans                           NaN        NaN        NaN        NaN
# Veenker Harlen G               NaN        NaN        NaN        NaN
# Yakovlev                       NaN        NaN        NaN        NaN
# Zipfell Mw                     NaN        NaN        NaN        NaN
#
# [265 rows x 6954 columns]

# %%
df_filter = df_table.apply(lambda s: s.dropna().iloc[:25].reset_index(drop=True), axis=1)
df_filter
# Out:
#                                      0               1              2   \
# manufacturername
# Aero Commander            United States       Australia  United States
# Aero Vodochody              Netherlands     Netherlands            NaN
# Aerospatiale                New Zealand   United States      Australia
# Aerospatiale Industries       Australia       Australia            NaN
# Aerospatiale/aeritalia    United States   United States  United States
# ...                                 ...             ...            ...
# Turczany Robert           United States   United States            NaN
# Vans                        Netherlands           Italy    Netherlands
# Veenker Harlen G          United States   United States            NaN
# Yakovlev                 United Kingdom  United Kingdom            NaN
# Zipfell Mw               United Kingdom  United Kingdom            NaN
#
#                                     3          4              5            6   \
# manufacturername
# Aero Commander           United States  Australia  United States          NaN
# Aero Vodochody                     NaN        NaN            NaN          NaN
# Aerospatiale             United States    Germany      Australia  New Zealand
# Aerospatiale Industries            NaN        NaN            NaN          NaN
# Aerospatiale/aeritalia   United States        NaN            NaN          NaN
# ...                                ...        ...            ...          ...
# Turczany Robert                    NaN        NaN            NaN          NaN
# Vans                             Italy        NaN            NaN          NaN
# Veenker Harlen G                   NaN        NaN            NaN          NaN
# Yakovlev                           NaN        NaN            NaN          NaN
# Zipfell Mw                         NaN        NaN            NaN          NaN
#
#                                     7          8              9   ...   15  \
# manufacturername                                                  ...
# Aero Commander                     NaN        NaN            NaN  ...  NaN
# Aero Vodochody                     NaN        NaN            NaN  ...  NaN
# Aerospatiale             United States  Australia  United States  ...  NaN
# Aerospatiale Industries            NaN        NaN            NaN  ...  NaN
# Aerospatiale/aeritalia             NaN        NaN            NaN  ...  NaN
# ...                                ...        ...            ...  ...  ...
# Turczany Robert                    NaN        NaN            NaN  ...  NaN
# Vans                               NaN        NaN            NaN  ...  NaN
# Veenker Harlen G                   NaN        NaN            NaN  ...  NaN
# Yakovlev                           NaN        NaN            NaN  ...  NaN
# Zipfell Mw                         NaN        NaN            NaN  ...  NaN
#
#                           16   17   18   19   20   21   22   23   24
# manufacturername
# Aero Commander           NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Aero Vodochody           NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Aerospatiale             NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Aerospatiale Industries  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Aerospatiale/aeritalia   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                      ...  ...  ...  ...  ...  ...  ...  ...  ...
# Turczany Robert          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Vans                     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Veenker Harlen G         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Yakovlev                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Zipfell Mw               NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [265 rows x 25 columns]

# %%
cleanedList = []
dflist = df_filter.values.tolist()

for i in range (265):
    currentList = [item for item in dflist[i] if not(pd.isnull(item)) == True]
    cleanedList.append(currentList)
    
cleanedList
# Out:
# [['United States',
#   'Australia',
#   'United States',
#   'United States',
#   'Australia',
#   'United States'],
#  ['Netherlands', 'Netherlands'],
#  ['New Zealand',
#   'United States',
#   'Australia',
#   'United States',
#   'Germany',
#   'Australia',
#   'New Zealand',
#   'United States',
#   'Australia',
#   'United States',
#   'Germany',
#   'Australia'],
#  ['Australia', 'Australia'],
#  ['United States', 'United States', 'United States', 'United States'],
#  ['United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom'],
#  ['United States', 'United States', 'United States', 'United States'],
#  ['Canada', 'Canada', 'Canada', 'Canada'],
#  ['Australia', 'Australia'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States'],
#  ['Australia', 'Australia'],
#  ['Portugal', 'Portugal'],
#  ['Australia',
#   'South Korea',
#   'Australia',
#   'Australia',
#   'Australia',
#   'United States',
#   'South Korea',
#   'South Korea',
#   'Japan',
#   'Australia',
#   'United States',
#   'Australia',
#   'South Korea',
#   'Japan',
#   'Australia',
#   'Australia',
#   'South Korea',
#   'Netherlands',
#   'Australia',
#   'Netherlands',
#   'Italy',
#   'Sweden',
#   'Sweden',
#   'Italy',
#   'Brazil'],
#  ['United States', 'United States', 'United States', 'United States'],
#  ['United States', 'United States'],
#  ['United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom'],
#  ['United Kingdom', 'United Kingdom'],
#  ['Australia', 'Australia'],
#  ['Japan',
#   'Taiwan',
#   'South Korea',
#   'South Korea',
#   'Japan',
#   'United States',
#   'South Korea',
#   'Saudi Arabia',
#   'India',
#   'United States',
#   'Australia',
#   'Australia',
#   'United States',
#   'Malaysia',
#   'New Zealand',
#   'Mexico',
#   'Taiwan',
#   'Taiwan',
#   'United States',
#   'United States',
#   'New Zealand',
#   'United States',
#   'Thailand',
#   'South Korea',
#   'New Zealand'],
#  ['United States', 'United States'],
#  ['United States', 'United States', 'United States', 'United States'],
#  ['United States',
#   'Australia',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Germany',
#   'United States',
#   'United States',
#   'Germany',
#   'Hong Kong',
#   'Hong Kong',
#   'Germany',
#   'Germany',
#   'France',
#   'Germany',
#   'Netherlands',
#   'Germany',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States'],
#  ['Australia',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'Australia',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom'],
#  ['Switzerland', 'Switzerland'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States'],
#  ['Germany', 'Germany'],
#  ['United States',
#   'Australia',
#   'United States',
#   'Canada',
#   'Canada',
#   'United States',
#   'Canada',
#   'Canada',
#   'United States',
#   'United States',
#   'United States',
#   'Belgium',
#   'United States',
#   'United States',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Australia',
#   'Germany',
#   'Germany',
#   'Italy',
#   'Netherlands',
#   'Italy',
#   'Ireland',
#   'Germany'],
#  ['Germany', 'Austria', 'Austria', 'Germany'],
#  ['Malaysia', 'France', 'France', 'Malaysia', 'France', 'France'],
#  ['United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'Germany',
#   'United Kingdom',
#   'United Kingdom',
#   'France',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United States',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'Jersey',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom'],
#  ['Australia', 'Australia', 'Australia', 'Australia'],
#  ['United States', 'United States'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States'],
#  ['France', 'France'],
#  ['United States', 'United States'],
#  ['United Kingdom', 'France'],
#  ['France', 'France'],
#  ['Ireland',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'Ireland',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'Ireland',
#   'United Kingdom',
#   'United Kingdom'],
#  ['New Zealand',
#   'Taiwan',
#   'Malaysia',
#   'New Zealand',
#   'New Zealand',
#   'Malaysia',
#   'New Zealand',
#   'India',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'Malaysia',
#   'Taiwan',
#   'Malaysia',
#   'Malaysia',
#   'New Zealand',
#   'Malaysia',
#   'Finland',
#   'New Zealand',
#   'Germany',
#   'India',
#   'New Zealand',
#   'New Zealand',
#   'Malaysia'],
#  ['United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom'],
#  ['Switzerland', 'Switzerland'],
#  ['Canada', 'Canada'],
#  ['Canada', 'Canada'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'Australia',
#   'United States',
#   'United States',
#   'Australia',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'New Zealand',
#   'Australia',
#   'United States',
#   'Austria',
#   'United States',
#   'United States',
#   'Sweden'],
#  ['Australia', 'Australia', 'Australia', 'Australia'],
#  ['Canada', 'Canada', 'Canada', 'Canada'],
#  ['Canada',
#   'United Kingdom',
#   'United Kingdom',
#   'Canada',
#   'United Kingdom',
#   'United Kingdom'],
#  ['Australia', 'Australia', 'Australia', 'Australia'],
#  ['United States',
#   'Poland',
#   'Poland',
#   'United States',
#   'United States',
#   'Poland',
#   'Poland',
#   'United States'],
#  ['United States',
#   'Australia',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'New Zealand',
#   'Australia',
#   'United States',
#   'New Zealand',
#   'New Zealand',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Sweden',
#   'United States',
#   'United States',
#   'Sweden',
#   'United States',
#   'Czech Republic',
#   'Sweden',
#   'United States'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States'],
#  ['Australia', 'United Kingdom', 'Australia', 'United Kingdom'],
#  ['Canada', 'Canada'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States'],
#  ['United States', 'United States'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Mexico',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Australia',
#   'United States',
#   'Japan',
#   'Italy',
#   'United States',
#   'United States',
#   'Japan',
#   'United States',
#   'United States'],
#  ['Hungary',
#   'Finland',
#   'Germany',
#   'Hungary',
#   'Germany',
#   'Estonia',
#   'Hungary',
#   'Denmark'],
#  ['United States', 'United States'],
#  ['United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'Germany',
#   'United Kingdom'],
#  ['New Zealand',
#   'Australia',
#   'Australia',
#   'Australia',
#   'New Zealand',
#   'Australia',
#   'New Zealand',
#   'New Zealand',
#   'Australia',
#   'Australia',
#   'New Zealand',
#   'Japan',
#   'New Zealand',
#   'Australia',
#   'New Zealand',
#   'Australia',
#   'Australia',
#   'New Zealand',
#   'Japan',
#   'Japan',
#   'Australia',
#   'United States',
#   'New Zealand',
#   'New Zealand',
#   'Australia'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Australia',
#   'United States',
#   'Canada',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Canada',
#   'United States',
#   'Australia'],
#  ['Canada',
#   'Canada',
#   'Canada',
#   'United States',
#   'Canada',
#   'Canada',
#   'United States',
#   'United States',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'United States',
#   'Australia',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada'],
#  ['Canada', 'Canada'],
#  ['New Zealand', 'New Zealand'],
#  ['Australia', 'Australia'],
#  ['Australia', 'Australia', 'Australia', 'Australia'],
#  ['New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand'],
#  ['Australia', 'Australia'],
#  ['Switzerland',
#   'Switzerland',
#   'Switzerland',
#   'Germany',
#   'Switzerland',
#   'Switzerland',
#   'Switzerland',
#   'Switzerland',
#   'Germany',
#   'Switzerland',
#   'Belgium',
#   'United Kingdom',
#   'Switzerland',
#   'Germany',
#   'United Kingdom',
#   'Switzerland',
#   'Belgium',
#   'Germany',
#   'Switzerland',
#   'United Kingdom',
#   'United Kingdom',
#   'Germany',
#   'Luxembourg',
#   'Switzerland',
#   'Switzerland'],
#  ['United Kingdom', 'United Kingdom'],
#  ['Australia', 'Australia', 'Australia', 'Australia'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Australia',
#   'United States',
#   'United States',
#   'United States',
#   'United States'],
#  ['Australia',
#   'New Zealand',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'New Zealand',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia'],
#  ['United States',
#   'Australia',
#   'Canada',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Canada',
#   'Canada',
#   'Australia',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Australia',
#   'Australia',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Canada',
#   'Canada',
#   'Australia'],
#  ['United States', 'United States'],
#  ['United Arab Emirates',
#   'United Arab Emirates',
#   'United Arab Emirates',
#   'United Arab Emirates',
#   'United Arab Emirates',
#   'United Arab Emirates',
#   'United Arab Emirates',
#   'United Arab Emirates',
#   'United Arab Emirates',
#   'United Arab Emirates',
#   'United Arab Emirates',
#   'United Arab Emirates',
#   'United Arab Emirates',
#   'United Arab Emirates',
#   'United Arab Emirates',
#   'United Arab Emirates',
#   'United Arab Emirates',
#   'United Arab Emirates'],
#  ['Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Switzerland',
#   'Belgium',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Germany',
#   'Belgium'],
#  ['Australia', 'Australia', 'Australia', 'Australia'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United States', 'United States'],
#  ['United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom'],
#  ['Australia', 'Switzerland', 'Australia', 'Switzerland'],
#  ['United States', 'United States'],
#  ['United States',
#   'United States',
#   'United Arab Emirates',
#   'Germany',
#   'Germany',
#   'Germany',
#   'Italy',
#   'Portugal',
#   'France',
#   'Italy',
#   'Italy',
#   'France',
#   'United States',
#   'United States',
#   'Qatar',
#   'Germany',
#   'United Kingdom',
#   'Germany',
#   'Italy',
#   'Portugal',
#   'France',
#   'Italy',
#   'Italy',
#   'United Kingdom'],
#  ['United States', 'United States'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United States', 'Denmark', 'Denmark', 'Canada', 'Sweden', 'Denmark'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United Kingdom', 'United Kingdom'],
#  ['Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Germany',
#   'Germany',
#   'Austria',
#   'Austria',
#   'Austria',
#   'Austria',
#   'Germany',
#   'Austria',
#   'Italy',
#   'Italy',
#   'Czech Republic',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Germany',
#   'Germany',
#   'Austria',
#   'Austria',
#   'Austria',
#   'Austria'],
#  ['United States', 'United States'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States'],
#  ['Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia'],
#  ['Switzerland', 'Switzerland', 'Switzerland', 'Switzerland'],
#  ['Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia'],
#  ['Germany',
#   'Germany',
#   'Germany',
#   'Portugal',
#   'Germany',
#   'Germany',
#   'Germany',
#   'Portugal'],
#  ['United Kingdom', 'United Kingdom'],
#  ['France', 'France'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Australia',
#   'United States',
#   'Canada',
#   'United States',
#   'United States',
#   'Romania',
#   'Latvia',
#   'Lithuania',
#   'Poland',
#   'Poland',
#   'Austria',
#   'Austria',
#   'Poland',
#   'Germany',
#   'Poland',
#   'Belgium',
#   'Croatia',
#   'Germany'],
#  ['Switzerland', 'Hungary'],
#  ['United States',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'United States',
#   'United States',
#   'Canada'],
#  ['United States', 'United States', 'Canada', 'Canada'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States'],
#  ['Belgium', 'United Kingdom'],
#  ['Canada',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Canada',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States'],
#  ['Canada',
#   'United States',
#   'Poland',
#   'Canada',
#   'United States',
#   'Canada',
#   'Poland',
#   'Canada'],
#  ['Guernsey',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'Guernsey',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'Guernsey',
#   'United Kingdom',
#   'United Kingdom'],
#  ['United States', 'United States'],
#  ['Germany', 'United Kingdom', 'United Kingdom', 'Germany'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'New Zealand',
#   'United States',
#   'New Zealand',
#   'United States',
#   'New Zealand',
#   'United States',
#   'Australia',
#   'New Zealand',
#   'United States',
#   'United States',
#   'United States',
#   'New Zealand',
#   'United States',
#   'New Zealand',
#   'United States',
#   'United States',
#   'United States',
#   'Australia',
#   'United States',
#   'United States',
#   'Netherlands'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States'],
#  ['Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia'],
#  ['Australia', 'Australia'],
#  ['United States', 'United States'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States'],
#  ['Canada', 'Canada'],
#  ['Australia', 'Australia'],
#  ['Czech Republic', 'Czech Republic', 'Czech Republic', 'Czech Republic'],
#  ['United Kingdom', 'United Kingdom'],
#  ['Philippines',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Philippines',
#   'Australia',
#   'Australia',
#   'Australia'],
#  ['Australia', 'Australia', 'Australia', 'Australia'],
#  ['Belgium', 'France'],
#  ['United States', 'United States'],
#  ['United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom'],
#  ['Canada', 'Canada', 'Canada', 'Canada'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States'],
#  ['New Zealand',
#   'France',
#   'France',
#   'Spain',
#   'New Zealand',
#   'France',
#   'France',
#   'Spain'],
#  ['Morocco', 'Spain'],
#  ['United States',
#   'United States',
#   'United States',
#   'Belgium',
#   'Germany',
#   'United States',
#   'United Kingdom',
#   'Switzerland',
#   'Taiwan',
#   'United States',
#   'Poland',
#   'United States',
#   'Dominican Republic',
#   'United States',
#   'Sweden',
#   'Germany',
#   'United States',
#   'France',
#   'Spain',
#   'Taiwan',
#   'United States',
#   'Poland'],
#  ['United States', 'United States', 'United States', 'United States'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'Germany',
#   'India',
#   'Australia',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Germany',
#   'India',
#   'Australia'],
#  ['Australia', 'Australia'],
#  ['Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Switzerland',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Switzerland'],
#  ['United Kingdom', 'United Kingdom'],
#  ['New Zealand', 'New Zealand', 'New Zealand', 'New Zealand'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United Kingdom', 'United Kingdom'],
#  ['Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia'],
#  ['United Kingdom', 'United Kingdom'],
#  ['Russia', 'Russia'],
#  ['United States', 'United States'],
#  ['Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia'],
#  ['Belgium', 'Belgium'],
#  ['United Kingdom', 'United Kingdom'],
#  ['Australia', 'Australia'],
#  ['United States', 'United States'],
#  ['United States', 'United States', 'United States', 'United States'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United Kingdom',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Guernsey',
#   'United States'],
#  ['United States',
#   'United States',
#   'Sweden',
#   'Norway',
#   'United States',
#   'United States',
#   'Sweden',
#   'Norway'],
#  ['New Zealand', 'New Zealand'],
#  ['Australia', 'Australia', 'Australia', 'Australia'],
#  ['United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom'],
#  ['Czech Republic', 'Czech Republic', 'Czech Republic', 'Switzerland'],
#  ['United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom'],
#  ['Canada', 'United Kingdom', 'Canada', 'United Kingdom'],
#  ['Australia', 'Australia'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United States', 'United States'],
#  ['Germany', 'Germany'],
#  ['New Zealand', 'New Zealand'],
#  ['Canada',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States'],
#  ['Australia', 'Australia'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States'],
#  ['United States', 'United States'],
#  ['United States', 'United States'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United States', 'United States'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom'],
#  ['New Zealand', 'New Zealand'],
#  ['Australia', 'Australia', 'Australia', 'Australia'],
#  ['Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United Kingdom', 'United Kingdom'],
#  ['France', 'France'],
#  ['Australia', 'Australia'],
#  ['Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'United States',
#   'Australia',
#   'Australia',
#   'United States',
#   'New Zealand',
#   'Australia',
#   'New Zealand',
#   'New Zealand',
#   'Australia',
#   'Australia',
#   'New Zealand',
#   'United Kingdom',
#   'Australia',
#   'Finland',
#   'Australia',
#   'Australia',
#   'United States',
#   'South Africa',
#   'Finland',
#   'New Zealand'],
#  ['Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Australia',
#   'United States',
#   'Australia',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Australia',
#   'United States',
#   'United Kingdom',
#   'Australia',
#   'United States',
#   'United States'],
#  ['Canada',
#   'Canada',
#   'Switzerland',
#   'Switzerland',
#   'Germany',
#   'Switzerland',
#   'Canada',
#   'Canada',
#   'Germany',
#   'Switzerland',
#   'Germany',
#   'Switzerland'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Australia',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Australia',
#   'United States',
#   'Australia',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United Kingdom',
#   'Switzerland',
#   'Austria',
#   'United Kingdom'],
#  ['Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia'],
#  ['New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'Australia',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'New Zealand',
#   'Australia'],
#  ['Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Australia',
#   'Canada',
#   'Canada',
#   'Australia',
#   'Australia',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom'],
#  ['United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom'],
#  ['Australia', 'Canada', 'Australia', 'Canada'],
#  ['New Zealand', 'New Zealand', 'New Zealand', 'New Zealand'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United States', 'United States'],
#  ['Australia', 'Australia'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Australia',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Australia',
#   'Canada',
#   'Germany',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Isle of Man',
#   'United Kingdom'],
#  ['United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom'],
#  ['United States', 'United States'],
#  ['Austria', 'Austria'],
#  ['United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom'],
#  ['Netherlands', 'Germany'],
#  ['Austria',
#   'Belgium',
#   'Netherlands',
#   'Germany',
#   'France',
#   'Germany',
#   'Belgium',
#   'Portugal',
#   'Netherlands',
#   'Austria',
#   'Austria',
#   'Belgium',
#   'Netherlands',
#   'Germany',
#   'France',
#   'Germany',
#   'Belgium',
#   'Portugal',
#   'Netherlands',
#   'Austria'],
#  ['Germany', 'Germany', 'Germany', 'Germany'],
#  ['France',
#   'France',
#   'France',
#   'France',
#   'France',
#   'France',
#   'France',
#   'France',
#   'France',
#   'France',
#   'France',
#   'France',
#   'France',
#   'France',
#   'France',
#   'France',
#   'France',
#   'France'],
#  ['Australia',
#   'Australia',
#   'Japan',
#   'New Zealand',
#   'Australia',
#   'Denmark',
#   'Denmark',
#   'Australia',
#   'Australia',
#   'Japan',
#   'New Zealand',
#   'Australia',
#   'Denmark',
#   'Denmark'],
#  ['Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'United States',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'United States',
#   'Australia'],
#  ['United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom'],
#  ['Australia', 'Australia'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'Switzerland',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Austria'],
#  ['United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom'],
#  ['United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United Kingdom', 'United Kingdom'],
#  ['Japan', 'Japan', 'Japan', 'Japan', 'Japan', 'Japan', 'Japan', 'Japan'],
#  ['Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia'],
#  ['Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia'],
#  ['Australia', 'Australia'],
#  ['United States', 'United States'],
#  ['New Zealand', 'New Zealand'],
#  ['Canada', 'Australia', 'Canada', 'Australia'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United States', 'United States'],
#  ['United States', 'United States', 'United States', 'United States'],
#  ['Australia',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Australia',
#   'Austria',
#   'Ireland',
#   'Australia',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Australia',
#   'Austria',
#   'Ireland'],
#  ['Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Canada'],
#  ['United Kingdom', 'United Kingdom'],
#  ['Canada', 'Canada', 'Canada', 'Canada'],
#  ['United States',
#   'United States',
#   'France',
#   'France',
#   'France',
#   'United States',
#   'United States',
#   'France',
#   'France',
#   'France'],
#  ['United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom'],
#  ['United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom'],
#  ['United Kingdom', 'United Kingdom'],
#  ['Russia', 'Russia', 'Russia', 'Russia'],
#  ['Australia', 'United States', 'Australia', 'United States'],
#  ['Germany', 'Germany'],
#  ['United Kingdom', 'United Kingdom'],
#  ['French Polynesia', 'Germany', 'French Polynesia', 'Germany'],
#  ['Netherlands',
#   'Sweden',
#   'France',
#   'Switzerland',
#   'Spain',
#   'Switzerland',
#   'Switzerland',
#   'Netherlands',
#   'Spain',
#   'Switzerland',
#   'Sweden',
#   'Switzerland',
#   'France',
#   'Spain',
#   'France',
#   'France',
#   'Switzerland',
#   'Spain'],
#  ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'France',
#   'United States',
#   'Mexico',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States'],
#  ['Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'United Kingdom',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'United Kingdom'],
#  ['Australia', 'Australia', 'Australia', 'Australia'],
#  ['Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia'],
#  ['Canada',
#   'Canada',
#   'Canada',
#   'United States',
#   'Germany',
#   'Canada',
#   'Australia',
#   'Canada',
#   'Canada',
#   'Canada',
#   'Australia',
#   'Canada',
#   'United States',
#   'United Kingdom',
#   'Canada',
#   'Sweden',
#   'Italy',
#   'Australia',
#   'United Kingdom',
#   'Spain',
#   'Portugal',
#   'Belgium',
#   'Portugal',
#   'United Kingdom',
#   'Belgium'],
#  ['Canada', 'Canada'],
#  ['United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom'],
#  ['Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia',
#   'Australia'],
#  ['United States', 'United States'],
#  ['New Zealand', 'New Zealand'],
#  ['United States', 'United States'],
#  ['Netherlands', 'Italy', 'Netherlands', 'Italy'],
#  ['United States', 'United States'],
#  ['United Kingdom', 'United Kingdom'],
#  ['United Kingdom', 'United Kingdom']]

# %%
#membuat tiap row hanya berisi unique value
cleanedList2 = [[] for _ in range(256)]
for i in range (256):
    for item in cleanedList[i]:
        if item in cleanedList2[i]:
            continue
        else:
            cleanedList2[i].append(item)
            
cleanedList2
# Out:
# [['United States', 'Australia'],
#  ['Netherlands'],
#  ['New Zealand', 'United States', 'Australia', 'Germany'],
#  ['Australia'],
#  ['United States'],
#  ['United Kingdom'],
#  ['United States'],
#  ['Canada'],
#  ['Australia'],
#  ['United States'],
#  ['Australia'],
#  ['Portugal'],
#  ['Australia',
#   'South Korea',
#   'United States',
#   'Japan',
#   'Netherlands',
#   'Italy',
#   'Sweden',
#   'Brazil'],
#  ['United States'],
#  ['United States'],
#  ['United Kingdom'],
#  ['United Kingdom'],
#  ['Australia'],
#  ['Japan',
#   'Taiwan',
#   'South Korea',
#   'United States',
#   'Saudi Arabia',
#   'India',
#   'Australia',
#   'Malaysia',
#   'New Zealand',
#   'Mexico',
#   'Thailand'],
#  ['United States'],
#  ['United States'],
#  ['United States',
#   'Australia',
#   'Germany',
#   'Hong Kong',
#   'France',
#   'Netherlands',
#   'United Kingdom'],
#  ['United States'],
#  ['Australia', 'United Kingdom'],
#  ['Switzerland'],
#  ['United States'],
#  ['Germany'],
#  ['United States',
#   'Australia',
#   'Canada',
#   'Belgium',
#   'Germany',
#   'Italy',
#   'Netherlands',
#   'Ireland'],
#  ['Germany', 'Austria'],
#  ['Malaysia', 'France'],
#  ['United Kingdom', 'Germany', 'France', 'United States', 'Jersey'],
#  ['Australia'],
#  ['United States'],
#  ['United States'],
#  ['United States'],
#  ['France'],
#  ['United States'],
#  ['United Kingdom', 'France'],
#  ['France'],
#  ['Ireland', 'United Kingdom'],
#  ['New Zealand', 'Taiwan', 'Malaysia', 'India', 'Finland', 'Germany'],
#  ['United Kingdom'],
#  ['Switzerland'],
#  ['Canada'],
#  ['Canada'],
#  ['United States', 'Australia', 'New Zealand', 'Austria', 'Sweden'],
#  ['Australia'],
#  ['Canada'],
#  ['Canada', 'United Kingdom'],
#  ['Australia'],
#  ['United States', 'Poland'],
#  ['United States', 'Australia', 'New Zealand', 'Sweden', 'Czech Republic'],
#  ['United Kingdom'],
#  ['United States'],
#  ['Australia', 'United Kingdom'],
#  ['Canada'],
#  ['United States'],
#  ['United States'],
#  ['United States', 'Mexico', 'Australia', 'Japan', 'Italy'],
#  ['Hungary', 'Finland', 'Germany', 'Estonia', 'Denmark'],
#  ['United States'],
#  ['United Kingdom', 'Germany'],
#  ['New Zealand', 'Australia', 'Japan', 'United States'],
#  ['United States', 'Australia', 'Canada'],
#  ['Canada', 'United States', 'Australia'],
#  ['Canada'],
#  ['New Zealand'],
#  ['Australia'],
#  ['Australia'],
#  ['New Zealand'],
#  ['Australia'],
#  ['Switzerland', 'Germany', 'Belgium', 'United Kingdom', 'Luxembourg'],
#  ['United Kingdom'],
#  ['Australia'],
#  ['United Kingdom'],
#  ['United States', 'Australia'],
#  ['Australia', 'New Zealand'],
#  ['United States', 'Australia', 'Canada'],
#  ['United States'],
#  ['United Arab Emirates'],
#  ['Sweden'],
#  ['United States', 'Switzerland', 'Belgium', 'United Kingdom', 'Germany'],
#  ['Australia'],
#  ['United Kingdom'],
#  ['United States'],
#  ['United Kingdom'],
#  ['Australia', 'Switzerland'],
#  ['United States'],
#  ['United States',
#   'United Arab Emirates',
#   'Germany',
#   'Italy',
#   'Portugal',
#   'France',
#   'Qatar',
#   'United Kingdom'],
#  ['United States'],
#  ['United Kingdom'],
#  ['United States', 'Denmark', 'Canada', 'Sweden'],
#  ['United Kingdom'],
#  ['United Kingdom'],
#  ['Australia', 'Germany', 'Austria', 'Italy', 'Czech Republic'],
#  ['United States'],
#  ['United States'],
#  ['Australia'],
#  ['Switzerland'],
#  ['Australia'],
#  ['Germany', 'Portugal'],
#  ['United Kingdom'],
#  ['France'],
#  ['United States',
#   'Australia',
#   'Canada',
#   'Romania',
#   'Latvia',
#   'Lithuania',
#   'Poland',
#   'Austria',
#   'Germany',
#   'Belgium',
#   'Croatia'],
#  ['Switzerland', 'Hungary'],
#  ['United States', 'Canada'],
#  ['United States', 'Canada'],
#  ['United Kingdom'],
#  ['United States'],
#  ['Belgium', 'United Kingdom'],
#  ['Canada', 'United States'],
#  ['Canada', 'United States', 'Poland'],
#  ['Guernsey', 'United Kingdom'],
#  ['United States'],
#  ['Germany', 'United Kingdom'],
#  ['United Kingdom'],
#  ['United States', 'New Zealand', 'Australia', 'Netherlands'],
#  ['United States'],
#  ['Australia'],
#  ['Australia'],
#  ['United States'],
#  ['United States'],
#  ['Canada'],
#  ['Australia'],
#  ['Czech Republic'],
#  ['United Kingdom'],
#  ['Philippines', 'Australia'],
#  ['Australia'],
#  ['Belgium', 'France'],
#  ['United States'],
#  ['United Kingdom'],
#  ['Canada'],
#  ['United Kingdom'],
#  ['United Kingdom'],
#  ['United States'],
#  ['New Zealand', 'France', 'Spain'],
#  ['Morocco', 'Spain'],
#  ['United States',
#   'Belgium',
#   'Germany',
#   'United Kingdom',
#   'Switzerland',
#   'Taiwan',
#   'Poland',
#   'Dominican Republic',
#   'Sweden',
#   'France',
#   'Spain'],
#  ['United States'],
#  ['United Kingdom'],
#  ['United States', 'Germany', 'India', 'Australia'],
#  ['Australia'],
#  ['Australia', 'Switzerland'],
#  ['United Kingdom'],
#  ['New Zealand'],
#  ['United Kingdom'],
#  ['United Kingdom'],
#  ['Australia'],
#  ['United Kingdom'],
#  ['Russia'],
#  ['United States'],
#  ['Australia'],
#  ['Belgium'],
#  ['United Kingdom'],
#  ['Australia'],
#  ['United States'],
#  ['United States'],
#  ['United States', 'United Kingdom', 'Guernsey'],
#  ['United States', 'Sweden', 'Norway'],
#  ['New Zealand'],
#  ['Australia'],
#  ['United Kingdom'],
#  ['Czech Republic', 'Switzerland'],
#  ['United Kingdom'],
#  ['Canada', 'United Kingdom'],
#  ['Australia'],
#  ['United Kingdom'],
#  ['United Kingdom'],
#  ['United Kingdom'],
#  ['United States'],
#  ['Germany'],
#  ['New Zealand'],
#  ['Canada', 'United States'],
#  ['Australia'],
#  ['United Kingdom'],
#  ['United States'],
#  ['United Kingdom'],
#  ['United States'],
#  ['United States'],
#  ['United States'],
#  ['United Kingdom'],
#  ['United States'],
#  ['United Kingdom'],
#  ['United Kingdom'],
#  ['New Zealand'],
#  ['Australia'],
#  ['Australia'],
#  ['United Kingdom'],
#  ['United Kingdom'],
#  ['France'],
#  ['Australia'],
#  ['Australia',
#   'United States',
#   'New Zealand',
#   'United Kingdom',
#   'Finland',
#   'South Africa'],
#  ['Australia'],
#  ['United States', 'Australia', 'United Kingdom'],
#  ['Canada', 'Switzerland', 'Germany'],
#  ['United Kingdom'],
#  ['United Kingdom'],
#  ['United States', 'Australia', 'United Kingdom', 'Switzerland', 'Austria'],
#  ['Australia'],
#  ['New Zealand', 'Australia'],
#  ['Canada', 'Australia', 'United Kingdom'],
#  ['United Kingdom'],
#  ['Australia', 'Canada'],
#  ['New Zealand'],
#  ['United Kingdom'],
#  ['United States'],
#  ['Australia'],
#  ['United States',
#   'Australia',
#   'Canada',
#   'Germany',
#   'Isle of Man',
#   'United Kingdom'],
#  ['United Kingdom'],
#  ['United States'],
#  ['Austria'],
#  ['United Kingdom'],
#  ['Netherlands', 'Germany'],
#  ['Austria', 'Belgium', 'Netherlands', 'Germany', 'France', 'Portugal'],
#  ['Germany'],
#  ['France'],
#  ['Australia', 'Japan', 'New Zealand', 'Denmark'],
#  ['Australia', 'United States'],
#  ['United Kingdom'],
#  ['Australia'],
#  ['United States', 'Switzerland', 'Austria'],
#  ['United Kingdom'],
#  ['United Kingdom'],
#  ['United Kingdom'],
#  ['United Kingdom'],
#  ['Japan'],
#  ['Australia'],
#  ['Australia'],
#  ['Australia'],
#  ['United States'],
#  ['New Zealand'],
#  ['Canada', 'Australia'],
#  ['United Kingdom'],
#  ['United Kingdom'],
#  ['United States'],
#  ['United States'],
#  ['Australia', 'United States', 'Austria', 'Ireland'],
#  ['Canada'],
#  ['United Kingdom'],
#  ['Canada'],
#  ['United States', 'France'],
#  ['United Kingdom'],
#  ['United Kingdom'],
#  ['United Kingdom'],
#  ['Russia'],
#  ['Australia', 'United States'],
#  ['Germany'],
#  ['United Kingdom'],
#  ['French Polynesia', 'Germany'],
#  ['Netherlands', 'Sweden', 'France', 'Switzerland', 'Spain'],
#  ['United States', 'France', 'Mexico'],
#  ['Australia', 'United Kingdom'],
#  ['Australia'],
#  ['Australia'],
#  ['Canada',
#   'United States',
#   'Germany',
#   'Australia',
#   'United Kingdom',
#   'Sweden',
#   'Italy',
#   'Spain',
#   'Portugal',
#   'Belgium'],
#  ['Canada']]

# %%
te = TransactionEncoder()
te_ary = te.fit(cleanedList2).transform(cleanedList2)

# %%
df_try = pd.DataFrame(te_ary, columns=te.columns_)
df_try
# Out:
#      Australia  Austria  Belgium  Brazil  Canada  Croatia  Czech Republic  \
# 0         True    False    False   False   False    False           False
# 1        False    False    False   False   False    False           False
# 2         True    False    False   False   False    False           False
# 3         True    False    False   False   False    False           False
# 4        False    False    False   False   False    False           False
# ..         ...      ...      ...     ...     ...      ...             ...
# 251       True    False    False   False   False    False           False
# 252       True    False    False   False   False    False           False
# 253       True    False    False   False   False    False           False
# 254       True    False     True   False    True    False           False
# 255      False    False    False   False    True    False           False
#
#      Denmark  Dominican Republic  Estonia  ...  South Africa  South Korea  \
# 0      False               False    False  ...         False        False
# 1      False               False    False  ...         False        False
# 2      False               False    False  ...         False        False
# 3      False               False    False  ...         False        False
# 4      False               False    False  ...         False        False
# ..       ...                 ...      ...  ...           ...          ...
# 251    False               False    False  ...         False        False
# 252    False               False    False  ...         False        False
# 253    False               False    False  ...         False        False
# 254    False               False    False  ...         False        False
# 255    False               False    False  ...         False        False
#
#      Spain  Sweden  Switzerland  Taiwan  Thailand  United Arab Emirates  \
# 0    False   False        False   False     False                 False
# 1    False   False        False   False     False                 False
# 2    False   False        False   False     False                 False
# 3    False   False        False   False     False                 False
# 4    False   False        False   False     False                 False
# ..     ...     ...          ...     ...       ...                   ...
# 251  False   False        False   False     False                 False
# 252  False   False        False   False     False                 False
# 253  False   False        False   False     False                 False
# 254   True    True        False   False     False                 False
# 255  False   False        False   False     False                 False
#
#      United Kingdom  United States
# 0             False           True
# 1             False          False
# 2             False           True
# 3             False          False
# 4             False           True
# ..              ...            ...
# 251            True          False
# 252           False          False
# 253           False          False
# 254            True           True
# 255           False          False
#
# [256 rows x 49 columns]

# %%
frequent_itemsets = apriori(df_try, min_support=0.025, use_colnames=True)
frequent_itemsets
# Out:
#      support                                  itemsets
# 0   0.292969                               (Australia)
# 1   0.035156                                 (Austria)
# 2   0.039062                                 (Belgium)
# 3   0.117188                                  (Canada)
# 4   0.066406                                  (France)
# 5   0.105469                                 (Germany)
# 6   0.031250                             (Netherlands)
# 7   0.078125                             (New Zealand)
# 8   0.035156                                  (Sweden)
# 9   0.054688                             (Switzerland)
# 10  0.308594                          (United Kingdom)
# 11  0.335938                           (United States)
# 12  0.039062                       (Australia, Canada)
# 13  0.031250                      (Australia, Germany)
# 14  0.039062                  (New Zealand, Australia)
# 15  0.039062               (United Kingdom, Australia)
# 16  0.097656                (United States, Australia)
# 17  0.027344                        (Belgium, Germany)
# 18  0.050781                   (United States, Canada)
# 19  0.039062                 (United Kingdom, Germany)
# 20  0.042969                  (United States, Germany)
# 21  0.027344              (New Zealand, United States)
# 22  0.027344                   (United States, Sweden)
# 23  0.042969           (United States, United Kingdom)
# 24  0.027344        (United States, Australia, Canada)
# 25  0.027344       (United States, Australia, Germany)
# 26  0.027344   (New Zealand, United States, Australia)
# 27  0.027344  (United States, United Kingdom, Germany)

# %%
from mlxtend.frequent_patterns import association_rules
res = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
res
# Out:
#                     antecedents      consequents  antecedent support  \
# 0                     (Belgium)        (Germany)            0.039062
# 1                      (Sweden)  (United States)            0.035156
# 2           (Australia, Canada)  (United States)            0.039062
# 3          (Australia, Germany)  (United States)            0.031250
# 4  (United States, New Zealand)      (Australia)            0.027344
# 5      (New Zealand, Australia)  (United States)            0.039062
# 6     (United Kingdom, Germany)  (United States)            0.039062
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.105469  0.027344    0.700000  6.637037  0.023224    2.981771
# 1            0.335938  0.027344    0.777778  2.315245  0.015533    2.988281
# 2            0.335938  0.027344    0.700000  2.083721  0.014221    2.213542
# 3            0.335938  0.027344    0.875000  2.604651  0.016846    5.312500
# 4            0.292969  0.027344    1.000000  3.413333  0.019333         inf
# 5            0.335938  0.027344    0.700000  2.083721  0.014221    2.213542
# 6            0.335938  0.027344    0.700000  2.083721  0.014221    2.213542

# %%
res1 = res[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
res1
# Out:
#                     antecedents      consequents   support  confidence  \
# 0                     (Belgium)        (Germany)  0.027344    0.700000
# 1                      (Sweden)  (United States)  0.027344    0.777778
# 2           (Australia, Canada)  (United States)  0.027344    0.700000
# 3          (Australia, Germany)  (United States)  0.027344    0.875000
# 4  (United States, New Zealand)      (Australia)  0.027344    1.000000
# 5      (New Zealand, Australia)  (United States)  0.027344    0.700000
# 6     (United Kingdom, Germany)  (United States)  0.027344    0.700000
#
#        lift
# 0  6.637037
# 1  2.315245
# 2  2.083721
# 3  2.604651
# 4  3.413333
# 5  2.083721
# 6  2.083721

# %%
res2 = res1[res1['confidence'] >= 1]
res2
# Out:
#                     antecedents  consequents   support  confidence      lift
# 4  (United States, New Zealand)  (Australia)  0.027344         1.0  3.413333
